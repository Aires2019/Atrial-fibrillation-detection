# %%
from IPython.display import display
import wfdb
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.读取.hea文件

# %%
record = wfdb.rdheader('../data/files/04015')
display(record.__dict__)
# Out:
# {'adc_gain': [200.0, 200.0],
#  'adc_res': [12, 12],
#  'adc_zero': [0, 0],
#  'base_counter': None,
#  'base_date': None,
#  'base_time': datetime.time(9, 0),
#  'baseline': [0, 0],
#  'block_size': [0, 0],
#  'byte_offset': [None, None],
#  'checksum': [-27172, -28460],
#  'comments': [],
#  'counter_freq': None,
#  'd_signal': None,
#  'e_d_signal': None,
#  'e_p_signal': None,
#  'file_name': ['04015.dat', '04015.dat'],
#  'fmt': ['212', '212'],
#  'fs': 250,
#  'init_value': [-55, -42],
#  'n_sig': 2,
#  'p_signal': None,
#  'record_name': '04015',
#  'samps_per_frame': [1, 1],
#  'sig_len': 9205760,
#  'sig_name': ['ECG1', 'ECG2'],
#  'skew': [None, None],
#  'units': ['mV', 'mV']}

# %% [markdown]
# ### record函数
# record_name : 储存心电信号的路径;
#
# sampfrom : 起始位置；
#
# sampto : 终止位置；
#
# channels :optional，选择读取某个通道的数据，默认读取全部通道

# %%
record=wfdb.rdrecord('../data/files/08455', ) 
display(record.__dict__)
# Out:
# {'adc_gain': [200.0, 200.0],
#  'adc_res': [12, 12],
#  'adc_zero': [0, 0],
#  'base_counter': None,
#  'base_date': None,
#  'base_time': None,
#  'baseline': [0, 0],
#  'block_size': [0, 0],
#  'byte_offset': [None, None],
#  'checksum': [26384, 30966],
#  'comments': [],
#  'counter_freq': None,
#  'd_signal': None,
#  'e_d_signal': None,
#  'e_p_signal': None,
#  'file_name': ['08455.dat', '08455.dat'],
#  'fmt': ['212', '212'],
#  'fs': 250,
#  'init_value': [-55, -74],
#  'n_sig': 2,
#  'p_signal': array([[-0.275, -0.37 ],
#         [-0.245, -0.45 ],
#         [-0.305, -0.43 ],
#         ...,
#         [-0.24 , -0.52 ],
#         [-0.3  , -0.52 ],
#         [-0.27 , -0.565]]),
#  'record_name': '08455',
#  'samps_per_frame': [1, 1],
#  'sig_len': 9205760,
#  'sig_name': ['ECG1', 'ECG2'],
#  'skew': [None, None],
#  'units': ['mV', 'mV']}

# %% [markdown]
# fs：采样频率；
#
# n_sig：信号通道数；
#
# sig_len：信号长度；
#
# p_signal：模拟信号值，储存形式为ndarray或者是list；
#
# d_signal：数字信号值，储存形式为ndarray或者是list

# %%
record=wfdb.rdann('../data/files/04015', 'qrs' ) 
display(record.__dict__)
# Out:
# {'ann_len': 44005,
#  'aux_note': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ...],
#  'chan': array([0, 0, 0, ..., 0, 0, 0]),
#  'contained_labels': None,
#  'custom_labels': None,
#  'description': None,
#  'extension': 'qrs',
#  'fs': 250,
#  'label_store': None,
#  'num': array([0, 0, 0, ..., 0, 0, 0]),
#  'record_name': '04015',
#  'sample': array([     61,     200,     358, ..., 8999531, 8999734, 8999941]),
#  'subtype': array([0, 0, 0, ..., 0, 0, 0]),
#  'symbol': ['N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   'N',
#   ...]}

# %%
type=[]
rootdir = '../data/files'           # 设置根路径 
files = os.listdir(rootdir) #列出文件夹下所有的目录与文件
name_list=[]            # name_list=[100,101,...234]
ECG1=[]                 # 用MLII型导联采集的人
type={}                 # 标记及其数量
for file in files:
    if file[0:5] in name_list:   # 根据数据库实际情况调整熟知，这里判断的是每个文件的前三个字符
        continue
    else:
        name_list.append(file[0:5])
for name in name_list:      # 遍历每一个数据文件
    if name[0] not in ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0']:       # 跳过无用的文件
        continue
    elif name in ['00735','03665']:
        continue
    #print(name)
    record = wfdb.rdrecord(rootdir+'/'+name)  # 读取一条记录（100），不用加扩展名
    if 'ECG1' in record.sig_name:       # 这里我们记录MLIII导联的数据（也可以记录其他的，根据数据库的不同选择数据量多的一类导联方式即可）
        ECG1.append(name)               # 记录下这个人
    annotation = wfdb.rdann(rootdir+'/'+name, 'atr')  # 读取一条记录的atr文件，扩展名atr
    for symbol in annotation.symbol:            # 记录下这个人所有的标记类型
        if symbol in list(type.keys()):
            type[symbol]+=1
        else:
            type[symbol]=1
    print('sympbol_name',type)
# Out:
# sympbol_name {'+': 15}
# sympbol_name {'+': 181}
# sympbol_name {'+': 196}
# sympbol_name {'+': 211}
# sympbol_name {'+': 222}
# sympbol_name {'+': 239}
# sympbol_name {'+': 312}
# sympbol_name {'+': 329}
# sympbol_name {'+': 371}
# sympbol_name {'+': 394}
# sympbol_name {'+': 449}
# sympbol_name {'+': 462}
# sympbol_name {'+': 473}
# sympbol_name {'+': 474}
# sympbol_name {'+': 475}
# sympbol_name {'+': 480}
# sympbol_name {'+': 490}
# sympbol_name {'+': 494}
# sympbol_name {'+': 573}
# sympbol_name {'+': 590}
# sympbol_name {'+': 594}
# sympbol_name {'+': 601}
# sympbol_name {'+': 605}

# %%
record = wfdb.rdrecord('../data/mit-bih-normal-sinus-rhythm-database-1.0.0/16265')
print(record.sig_name)
# Out:
# ['ECG1', 'ECG2']

# %%
record = wfdb.rdrecord('../data/files/08455', # 文件所在路径
                       sampfrom=0, # 读取100这个记录的起点，从第0个点开始读
                       sampto=1000, # 读取记录的终点，到1000个点结束
                       physical=False, # 若为True则读取原始信号p_signal，如果为False则读取数字信号d_signal，默认为False
                       channel_names=['ECG1']) # 读取那个通道，也可以用channel_names指定某个通道;如channel_names=['MLII']

# 转为数字信号
signal = record.d_signal[0:1000]

# 绘制波形
plt.plot(signal)
plt.title("ECG Signal")
plt.show()

# %%
record = wfdb.rdrecord('../data/files/04015', # 文件所在路径
                       sampfrom=0, # 读取100这个记录的起点，从第0个点开始读
                       sampto=1000, # 读取记录的终点，到1000个点结束
                       physical=False, # 若为True则读取原始信号p_signal，如果为False则读取数字信号d_signal，默认为False
                       channel_names=['ECG1']) # 读取那个通道，也可以用channel_names指定某个通道;如channel_names=['MLII']

# 转为数字信号
signal = record.d_signal[0:1000]

# 绘制波形
plt.plot(signal)
plt.title("ECG Signal")


# 读取annatations
signal_ann = wfdb.rdann("../data/files/04015", "atr", sampfrom=0, sampto=1000)

# 将读取到的annatations的心拍绘制到心电图上
for index in signal_ann.sample:
    plt.scatter(index, signal[index][0], marker="*")

# 并打印出改心拍标注的类型
print(signal_ann.symbol)
plt.show()
# Out:
# ['+']

# %%
record = wfdb.rdrecord('../data/mit-bih-normal-sinus-rhythm-database-1.0.0/16265', # 文件所在路径
                       sampfrom=0, # 读取100这个记录的起点，从第0个点开始读
                       sampto=1000, # 读取记录的终点，到1000个点结束
                       physical=False, # 若为True则读取原始信号p_signal，如果为False则读取数字信号d_signal，默认为False
                       channel_names=['ECG1']) # 读取那个通道，也可以用channel_names指定某个通道;如channel_names=['MLII']

# 转为数字信号
signal = record.d_signal[0:1000]

# 绘制波形
plt.plot(signal)
plt.title("ECG Signal")


# 读取annatations
signal_ann = wfdb.rdann("../data/mit-bih-normal-sinus-rhythm-database-1.0.0/16265", "atr", sampfrom=0, sampto=1000)

# 将读取到的annatations的心拍绘制到心电图上
for index in signal_ann.sample:
    plt.scatter(index, signal[index][0], marker="*")

# 并打印出改心拍标注的类型
print(signal_ann.symbol)
plt.show()
# Out:
# ['|', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N']
